# %%
import pandas as pd
import datetime
import pymysql
from sqlalchemy import create_engine

df = pd.read_csv('resumo_semana_03_12_postos.csv', delimiter=';')
df.dtypes
# Out:
# CNPJ                 object
# RAZÃO                object
# FANTASIA             object
# ENDEREÇO             object
# NÚMERO               object
# COMPLEMENTO          object
# BAIRRO               object
# CEP                  object
# MUNICÍPIO            object
# ESTADO               object
# BANDEIRA             object
# PRODUTO              object
# UNIDADE DE MEDIDA    object
# PREÇO DE REVENDA     object
# DATA DA COLETA       object
# dtype: object

# %%
import pandas as pd
import datetime
import pymysql
from sqlalchemy import create_engine

df = pd.read_csv('resumo_semana_03_12_postos.csv', delimiter=';')
df.columns = map(str.lower, df.columns)
df.columns = df.columns.str.replace(' ', '_')
df.columns = df.columns.str.replace('í', 'i')
df.columns = df.columns.str.replace('é', 'e')
df.columns = df.columns.str.replace('ç', 'c')
df.columns = df.columns.str.replace('ú', 'u')
df.columns = df.columns.str.replace('á', 'a')
df.columns = df.columns.str.replace('ã', 'a')
df.columns = df.columns.str.replace('ç', 'c')
df.drop(['razao'], axis=1, inplace=True)
df.rename(columns={
    "data_da_coleta": "data_cotacao",
    "fantasia":"nome_fantasia",
    "endereco":"nome_rua",
    "numero":"numero_rua",
    "complemento":"complemento_endereco",
    "bairro":"bairro_endereco",
    "municipio":"municipio_endereco",
    "estado":"estado_endereco",
    "bandeira":"bandeira_posto",
    "produto":"nome_produto",
    "preco_de_revenda":"cotacao_produto_posto",
    "cep":"cep_endereco"
    }, inplace=True)

# %%
df.columns
# Out:
# Index(['cnpj', 'nome_fantasia', 'nome_rua', 'numero_rua',
#        'complemento_endereco', 'bairro_endereco', 'cep_endereco',
#        'municipio_endereco', 'estado_endereco', 'bandeira_posto',
#        'nome_produto', 'unidade_de_medida', 'cotacao_produto_posto',
#        'data_cotacao'],
#       dtype='object')

# %%
df = df[['data_cotacao', 'cnpj', 'nome_fantasia', 'nome_rua', 'numero_rua', 'complemento_endereco', 'bairro_endereco',	
         'cep_endereco', 'municipio_endereco', 'estado_endereco', 'bandeira_posto',	'nome_produto','cotacao_produto_posto']]

# %%
df

# %%
df['data_cotacao'] = df['data_cotacao'].str.replace('/','-')
df['data_cotacao'] = pd.to_datetime(df['data_cotacao'])
df['cotacao_produto_posto'] = df['cotacao_produto_posto'].str.replace(',','.')
df['cep_endereco'] = df['cep_endereco'].str.replace('-','')
df['complemento_endereco'] = df['complemento_endereco'].str.replace('XXXXXXXXXXXXXXXXXXXXX','')

df
# Out:
# C:\Users\Adilson Lucarelli\AppData\Local\Temp\ipykernel_2616\90664769.py:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['data_cotacao'] = pd.to_datetime(df['data_cotacao'])
#       data_cotacao                cnpj         nome_fantasia  \
# 0       2022-11-28  00.003.188/0001-21              COMPETRO
# 1       2022-11-28  00.003.188/0001-21              COMPETRO
# 2       2022-11-28  00.003.188/0001-21              COMPETRO
# 3       2022-11-30  19.791.896/0070-24  SUPERGASBRAS ENERGIA
# 4       2022-11-30  00.198.451/0001-85          TRR COLORADO
# ...            ...                 ...                   ...
# 13923   2022-01-12  07.473.735/0187-14                   NaN
# 13924   2022-11-30  13.725.116/0002-10                   NaN
# 13925   2022-11-30  43.054.266/0001-20                   NaN
# 13926   2022-11-29  11.685.159/0002-94                   NaN
# 13927   2022-11-28  45.633.079/0001-26                   NaN
#
#                               nome_rua numero_rua  \
# 0               RUA HUMBERTO DE CAMPOS        306
# 1               RUA HUMBERTO DE CAMPOS        306
# 2               RUA HUMBERTO DE CAMPOS        306
# 3      AVENIDA DEPUTADO PLÍNIO RIBEIRO       3220
# 4              RUA   DOMINGOS CALAZANS        518
# ...                                ...        ...
# 13923                  RODOVIA ERS-130       2285
# 13924          RUA JOSE TORAL QUERUBIM        733
# 13925       AVENIDA BORGES DE MEDEIROS         45
# 13926          AVENIDA DUQUE DE CAXIAS        563
# 13927                       AVENIDA C4        697
#
#                      complemento_endereco                bairro_endereco  \
# 0                                     NaN                 JARDIM ZULMIRA
# 1                                     NaN                 JARDIM ZULMIRA
# 2                                     NaN                 JARDIM ZULMIRA
# 3                                     NaN               JARDIM PALMEIRAS
# 4                                     NaN                      TRIANGULO
# ...                                   ...                            ...
# 13923                          KM    72.8                    SANTO ANDRE
# 13924                                 NaN  CONJUNTO HABITACIONAL REQUIAO
# 13925                                 NaN                  SALGADO FILHO
# 13926                                LOJA             JARDIM TERESOPOLIS
# 13927  QUADRA06                  LOTE  20             BRO JARDIM AMERICA
#
#       cep_endereco municipio_endereco    estado_endereco  \
# 0         18061000           SOROCABA          SAO PAULO
# 1         18061000           SOROCABA          SAO PAULO
# 2         18061000           SOROCABA          SAO PAULO
# 3         39402194      MONTES CLAROS       MINAS GERAIS
# 4         63041130  JUAZEIRO DO NORTE              CEARA
# ...            ...                ...                ...
# 13923     95912000            LAJEADO  RIO GRANDE DO SUL
# 13924     87047438            MARINGA             PARANA
# 13925     97040000        SANTA MARIA  RIO GRANDE DO SUL
# 13926     32681630              BETIM       MINAS GERAIS
# 13927     74265040            GOIANIA              GOIAS
#
#              bandeira_posto    nome_produto cotacao_produto_posto
# 0                    BRANCA          ETANOL                  3.49
# 1                    BRANCA      DIESEL S10                  6.44
# 2                    BRANCA  GASOLINA COMUM                  4.49
# 3      SUPERGASBRAS ENERGIA             GLP                120.00
# 4       NACIONAL GÁS BUTANO             GLP                110.00
# ...                     ...             ...                   ...
# 13923                BRANCA             GLP                103.00
# 13924              ULTRAGAZ             GLP                120.00
# 13925              LIQUIGÁS             GLP                114.00
# 13926   NACIONAL GÁS BUTANO             GLP                107.00
# 13927                BRANCA             GLP                120.00
#
# [13928 rows x 13 columns]

# %%
df['cotacao_produto_posto'] = df['cotacao_produto_posto'].astype(float)
df['cep_endereco'] = df['cep_endereco'].astype(int)
df
# Out:
#       data_cotacao                cnpj         nome_fantasia  \
# 0       2022-11-28  00.003.188/0001-21              COMPETRO
# 1       2022-11-28  00.003.188/0001-21              COMPETRO
# 2       2022-11-28  00.003.188/0001-21              COMPETRO
# 3       2022-11-30  19.791.896/0070-24  SUPERGASBRAS ENERGIA
# 4       2022-11-30  00.198.451/0001-85          TRR COLORADO
# ...            ...                 ...                   ...
# 13923   2022-01-12  07.473.735/0187-14                   NaN
# 13924   2022-11-30  13.725.116/0002-10                   NaN
# 13925   2022-11-30  43.054.266/0001-20                   NaN
# 13926   2022-11-29  11.685.159/0002-94                   NaN
# 13927   2022-11-28  45.633.079/0001-26                   NaN
#
#                               nome_rua numero_rua  \
# 0               RUA HUMBERTO DE CAMPOS        306
# 1               RUA HUMBERTO DE CAMPOS        306
# 2               RUA HUMBERTO DE CAMPOS        306
# 3      AVENIDA DEPUTADO PLÍNIO RIBEIRO       3220
# 4              RUA   DOMINGOS CALAZANS        518
# ...                                ...        ...
# 13923                  RODOVIA ERS-130       2285
# 13924          RUA JOSE TORAL QUERUBIM        733
# 13925       AVENIDA BORGES DE MEDEIROS         45
# 13926          AVENIDA DUQUE DE CAXIAS        563
# 13927                       AVENIDA C4        697
#
#                      complemento_endereco                bairro_endereco  \
# 0                                     NaN                 JARDIM ZULMIRA
# 1                                     NaN                 JARDIM ZULMIRA
# 2                                     NaN                 JARDIM ZULMIRA
# 3                                     NaN               JARDIM PALMEIRAS
# 4                                     NaN                      TRIANGULO
# ...                                   ...                            ...
# 13923                          KM    72.8                    SANTO ANDRE
# 13924                                 NaN  CONJUNTO HABITACIONAL REQUIAO
# 13925                                 NaN                  SALGADO FILHO
# 13926                                LOJA             JARDIM TERESOPOLIS
# 13927  QUADRA06                  LOTE  20             BRO JARDIM AMERICA
#
#        cep_endereco municipio_endereco    estado_endereco  \
# 0          18061000           SOROCABA          SAO PAULO
# 1          18061000           SOROCABA          SAO PAULO
# 2          18061000           SOROCABA          SAO PAULO
# 3          39402194      MONTES CLAROS       MINAS GERAIS
# 4          63041130  JUAZEIRO DO NORTE              CEARA
# ...             ...                ...                ...
# 13923      95912000            LAJEADO  RIO GRANDE DO SUL
# 13924      87047438            MARINGA             PARANA
# 13925      97040000        SANTA MARIA  RIO GRANDE DO SUL
# 13926      32681630              BETIM       MINAS GERAIS
# 13927      74265040            GOIANIA              GOIAS
#
#              bandeira_posto    nome_produto  cotacao_produto_posto
# 0                    BRANCA          ETANOL                   3.49
# 1                    BRANCA      DIESEL S10                   6.44
# 2                    BRANCA  GASOLINA COMUM                   4.49
# 3      SUPERGASBRAS ENERGIA             GLP                 120.00
# 4       NACIONAL GÁS BUTANO             GLP                 110.00
# ...                     ...             ...                    ...
# 13923                BRANCA             GLP                 103.00
# 13924              ULTRAGAZ             GLP                 120.00
# 13925              LIQUIGÁS             GLP                 114.00
# 13926   NACIONAL GÁS BUTANO             GLP                 107.00
# 13927                BRANCA             GLP                 120.00
#
# [13928 rows x 13 columns]

# %%
engine =  create_engine('mysql+pymysql://root:1234@localhost/tcc_anp')
df.to_sql('registro_cotacao_posto', engine, if_exists='append', index=False)
print("Carga incluida com sucesso.")
